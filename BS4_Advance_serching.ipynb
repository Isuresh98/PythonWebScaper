# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

getHtml=urlopen("https://esoft.lk/")
bs4object=BeautifulSoup(getHtml,"lxml")
nameList =bs4object.findAll(id)
for name in nameList:
    print (name.get_text())
# Out:
# Home - ESOFT Metro Campus
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                 ESOFT Metro Campus
#
# About
#
#  About Us
# Management
# Academics
# Campus Life
# Research
# News
# Alumni
# Career
# Branches
# Contact Us
#
#
#
#
# Faculties
#
#  School of Computing
#
#  Certificate Level
# Diploma Level
# Higher National Diploma Level
# Undergraduate Level
# Postgraduate Level
# Doctorate Level
#
#
#
#
# School of Business & Law
#
#  Certificate Level
# Diploma Level
# Higher National Diploma Level
# Undergraduate Level
# Postgraduate Level
# Doctorate Level
#
#
#
#
# School of Engineering
#
#  Certificate Level
# Diploma Level
# Higher National Diploma Level
# Undergraduate Level
# Postgraduate Level
# Doctorate Level
#
#
#
#
# School of Tourism & Hospitality
#
#  Certificate Level
# ...
