# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup



getHtml= urlopen("https://esoft.lk/")
bsobjet =BeautifulSoup(getHtml,"lxml")

for link in bsobjet.findAll ("a"):
    if 'href' in link.attrs:
        print(link.attrs['href'])
# Out:
# https://esoft.lk/
# https://esoft.lk
# #
# https://esoft.lk/about-us/
# https://esoft.lk/management/
# https://esoft.lk/academics/
# https://esoft.lk/campus-life/
# https://esoft.lk/research/
# https://esoft.lk/news/
# https://esoft.lk/alumni/
# https://esoft.lk/career/
# https://esoft.lk/branches/
# https://esoft.lk/contact-us/
# #
# https://esoft.lk/school-of-computing/
# https://esoft.lk/school-of-computing-sc/certificate-level-sc/
# https://esoft.lk/school-of-computing-sc/diploma-level-sc/
# https://esoft.lk/school-of-computing-sc/higher-national-diploma-level-sc/
# https://esoft.lk/school-of-computing-sc/undergraduate-level-sc/
# https://esoft.lk/school-of-computing-sc/postgraduate-level-sc/
# https://esoft.lk/school-of-computing-sc/doctorate-level-sc/
# https://esoft.lk/school-of-business-law/
# https://esoft.lk/school-of-business-and-law-sbl/certificate-level-sbl/
# https://esoft.lk/school-of-business-and-law-sbl/diploma-level-sbl/
# ...
