# %%
from urllib.request import urlopen 
from bs4 import BeautifulSoup
html =urlopen ("https://getintopc.com/")
Bsobject =BeautifulSoup(html.read(),'lxml')
print (Bsobject.prettify)
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
# ...
